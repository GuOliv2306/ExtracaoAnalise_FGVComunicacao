# %%
# Automação web
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.edge.service import Service as EdgeService
from selenium.webdriver.edge.options import Options as EdgeOption

# Gerenciamento automático de drivers
from webdriver_manager.microsoft import EdgeChromiumDriverManager

# Parsing HTML
from bs4 import BeautifulSoup

# Manipulação de dados
import pandas as pd

# Requisições HTTP
import requests

# Barra de progresso
from tqdm import tqdm

# Utilitários
import time

# %%
edge_options = EdgeOption()
edge_options.add_argument("--start-maximized")  # abre a janela maximizada

# O WebDriver Manager baixa e configura o driver automaticamente
service = EdgeService
options = EdgeOption()
driver = webdriver.Edge(service=service, options=options)

# %%
driver.get("https://www.letras.mus.br")
time.sleep(2) 

caixa_pesquisa = driver.find_element(By.ID, "headerInput")
time.sleep(2)    # espera 2 segundos para a página carregar

caixa_pesquisa.send_keys(input("Digite o nome do artista: "))
time.sleep(1)
artista= driver.find_element(By.CLASS_NAME, "suggest-artist")
artista.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[10], line 9
#       7 caixa_pesquisa.send_keys(input("Digite o nome do artista: "))
#       8 time.sleep(1)
# ----> 9 artista= driver.find_element(By.CLASS_NAME, "suggest-artist")
#      10 artista.click()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\selenium\webdriver\remote\webdriver.py:926, in WebDriver.find_element(self, by, value)
#     923         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     924     return elements[0]
# --> 926 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\selenium\webdriver\remote\webdriver.py:458, in WebDriver.execute(self, driver_command, params)
#     455 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     457 if response:
# --> 458     self.error_handler.check_response(response)
#     459     response["value"] = self._unwrap_value(response.get("value", None))
#     460     return response
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".suggest-artist"}
#   (Session info: MicrosoftEdge=139.0.3405.125); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff781a1e795+22117]
# 	(No symbol) [0x0x7ff78196ee10]
# 	GetHandleVerifier [0x0x7ff781ca4c3c+2669324]
# 	(No symbol) [0x0x7ff78178928b]
# 	(No symbol) [0x0x7ff78178957b]
# 	(No symbol) [0x0x7ff7817c9b47]
# 	(No symbol) [0x0x7ff7817aa82f]
# 	(No symbol) [0x0x7ff78177f68d]
# 	(No symbol) [0x0x7ff7817c762f]
# 	(No symbol) [0x0x7ff7817aa553]
# 	(No symbol) [0x0x7ff78177eb86]
# 	(No symbol) [0x0x7ff78177de11]
# 	(No symbol) [0x0x7ff78177e9b3]
# 	(No symbol) [0x0x7ff78187907d]
# 	(No symbol) [0x0x7ff781885fe8]
# 	GetHandleVerifier [0x0x7ff781aff287+942423]
# 	GetHandleVerifier [0x0x7ff781b08231+979201]
# 	(No symbol) [0x0x7ff78197c3c1]
# 	(No symbol) [0x0x7ff781974d74]
# 	(No symbol) [0x0x7ff781974ec3]
# 	(No symbol) [0x0x7ff781967026]
# 	BaseThreadInitThunk [0x0x7ffac173e8d7+23]
# 	RtlUserThreadStart [0x0x7ffac38bc34c+44]

# %%
soup=BeautifulSoup(driver.page_source, 'html.parser')
musicas=soup.find_all("a", class_="songList-table-songName")
musicas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 musicas=soup.find_all("a", class_="songList-table-songName")
#
# NameError: name 'soup' is not defined
