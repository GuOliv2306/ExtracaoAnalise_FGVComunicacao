# %%
import requests 
import json
import os
import time
import pandas as pd

# %%
url_base = 'https://uselessfacts.jsph.pl/api/v2/facts/random'
list_fatos = []

for _ in range(50):  # Collect 10 unique facts
    try:
        response = requests.get(url_base)
        response.raise_for_status()
        print('Conexão bem sucedida')
        dados = response.json()
        # Check if this fact's id is already in list_fatos
        if not any(fato['id'] == dados['id'] for fato in list_fatos):
            list_fatos.append(dados)
    except Exception as exc:
        print('Ocorreu um problema: %s' % (exc))
# Out:
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# Conexão bem sucedida
# ...

# %%
dados = list_fatos
df = pd.DataFrame(dados)
df
# Out:
#                                   id  \
# 0   80b79a49182ff57675721e18d31f1763
# 1   8cde127b92424ff4681cf06fdcab490f
# 2   22d7a37a952554c942edd1e5b608be71
# 3   038a73550cb199a070f45be7824c738e
# 4   55dd8170fec9b27caab00f0b96675144
# 5   29c04092542e313890d1ea0195aba86d
# 6   ca89075fd3a528c2be2feac0be27383a
# 7   9a7648a7ab73922728a2e68825b71a3a
# 8   46ea861a166c2395a4c70c74f7e3d91c
# 9   72be8a70dba147b1f1bf6d8840d43f88
# 10  61a59aa9db7b78894da6c20a70bdb160
# 11  69b77879a0187cf159db700b74000e67
# 12  aa973c0e0e06fd41ec814afd33252c81
# 13  62516dd4ec8fc4e3289ee971316bd155
# 14  a2431ba4bac75532e8ec9f36c76d44b6
# 15  d970122d4cc9d6ae7472ef34a8760fc2
# 16  26ce38f50c4bd0d6e36c1f011ebac02d
# 17  7df7a31df2a9fe82eb58c08ba002f2bb
# 18  2781366ffa6279ac04831226ad536abf
# 19  619b0bcdfc6e394724ee7538048bfab2
# 20  2a147fe8e22fea25b5137b9db3894856
# 21  7adc55e4ebe38917acfb3ad19551d47f
# 22  aca91f861880daaa4d91f4dfd66a3d4f
# 23  21fff753aba0a421046a641a0d1f07cf
# ...
