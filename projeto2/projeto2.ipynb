# %% [markdown]
# # Projeto 2 - Extração e Análise de Métricas em Redes Sociais
#
# Total: 0,5 Ponto
#
# Para executar as análises, não esqueça de instalar as bibliotecas necessárias em requirements.txt
#
# No terminal...
# ```bash
# pip install -r requirements.txt
# ```
# (Verifique se está na pasta do mesmo arquivo requirements.txt. Para descobrir, digite `dir` e veja se o arquivo aparece na lista)

# %%
aluno = input('Qual o nome do(s) aluno(s)?:   ')
print(f'Aluno(s) {aluno} registrado(s) com sucesso!')
# Out:
# Aluno(s)  registrado(s) com sucesso!

# %% [markdown]
# ### 0) Preparação
#
# Escolha uma base da pasta "bases" que se inicie com "tktk_" e termine com ".csv", e abra-a. Caso queira utilizar uma base própria, seja do Instagram ou TikTok, sinta-se à vontade. Atente que, caso a base escolhida não seja uma da pasta, você precisará tratá-la adequadamente. Abaixo, segue um código de exemplo para tratar uma base do Tiktok oriunda do Zeeschuimer.
#
# ```python
# colunas_desejadas = ['id', 'desc', 'challenges', 'createTime', 'video.duration', 'video.cover', 'author.id',
#                 'author.nickname', 'author.uniqueId','author.verified', 'music.title', 'authorStats.followingCount',
#                 'authorStats.followerCount', 'authorStats.heartCount', 'authorStats.videoCount',
#                 'authorStats.diggCount', 'authorStats.heart', 'statsV2.collectCount', 'statsV2.commentCount',
#                 'statsV2.diggCount', 'statsV2.playCount', 'statsV2.shareCount']
# df = df[colunas_desejadas]
# df['createdAt'] = df['createTime'].apply(lambda x: pd.Timestamp(x, unit='s'))
#
# def preenche_url(item):
#     return f"https://www.tiktok.com/@{item['author.uniqueId']}/video/{item['id']}"
#
# df['url'] = df.apply(preenche_url, axis=1)
# df['statsV2.diggCount'] = df['statsV2.diggCount'].astype(float)
# df['statsV2.playCount'] = df['statsV2.playCount'].astype(float)
# df['statsV2.shareCount'] = df['statsV2.shareCount'].astype(float)
# df['statsV2.commentCount'] = df['statsV2.commentCount'].astype(float)
# df['statsV2.collectCount'] = df['statsV2.collectCount'].astype(float)
#
# def get_hashtags(lista):
#     resultado = []
#     try:
#         for item in lista:
#             resultado.append(item['title'])
#         return resultado
#     except:
#         return resultado
#
# df['hashtags'] = df['challenges'].apply(get_hashtags)
# ```
#
# As bases do TikTok disponíveis na pasta "bases" são:
#
# - tktk_base1.csv
# - tktk_base2.csv
# - tktk_base3.csv
#
# ### Lembrete: todos os gráficos gerados tem que ser LEGÍVEIS, ou seja, interpretáveis. Faça escolhas razoáveis para que os gráficos estejam de acordo.
#
# ### 1) Abertura da base e estatísticas gerais (0,1)
#
# Abra a base escolhida, exiba as primeiras 15 linhas, e mostre, para **cada variável numérica** da base, a contagem de linhas, a média, o mínimo, o percentil 25%, a mediana (percentil 50%), o percentil 75%, o máximo e o desvio padrão. (0,05)
#
# Abaixo do código, faça um comentário interpretativo sobre o que você observou nos resultados. (0,05)

# %%
import pandas as pd

df= pd.read_csv('tktk_base1.csv')
display(df.head(15))
display(df.describe())
# Out:
#     AIGCDescription  CategoryType  backendSourceEventTracking  \
# 0               NaN           101                         NaN
# 1               NaN           104                         NaN
# 2               NaN           101                         NaN
# 3               NaN           119                         NaN
# 4               NaN           120                         NaN
# 5               NaN           104                         NaN
# 6               NaN             0                         NaN
# 7               NaN           120                         NaN
# 8               NaN             0                         NaN
# 9               NaN           104                         NaN
# 10              NaN           114                         NaN
# 11              NaN           104                         NaN
# 12              NaN             0                         NaN
# 13              NaN           104                         NaN
# 14              NaN             0                         NaN
#
#                                            challenges  collected  \
# 0   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 1                                                 NaN      False
# 2   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 3   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 4   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 5                                                 NaN      False
# 6   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 7   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 8   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 9   [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 10  [{'coverLarger': 'https://p16-amd-va.tiktokcdn...      False
# 11  [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 12  [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 13  [{'coverLarger': '', 'coverMedium': '', 'cover...      False
# 14                                                NaN      False
#
#                                              contents  createTime  \
# 0   [{'desc': 'foi preso #felca #felcacamp #edit #...  1756141425
# 1   [{'desc': 'o FELCA de um jeito que a web nunca...  1745183232
# 2   [{'desc': '#felca #felcaedit #altashoras #pole...  1755426372
# 3   [{'desc': '#Hytalo #kamilinha #Felca', 'textEx...  1755528190
# 4   [{'desc': 'Felca contando pra Cela que ele é X...  1749583504
# 5                                                 NaN  1752634484
# 6   [{'desc': '@Felca @Yasmin Yassine ', 'textExtr...  1754238995
# 7   [{'desc': 'Felca> kamilinha '}, {'desc': 'Felc...  1754880091
# 8   [{'desc': 'ROSAS 🤣 #felca #felcalive #felcaedi...  1694391397
# 9   [{'desc': 'kkkkkk '}, {'desc': ''}, {'desc': '...  1751683686
# 10  [{'desc': 'Esquerda e Felca - uma análise da s...  1755386959
# 11  [{'desc': 'A filha perdida do Felca😂😱 #felca #...  1755382946
# 12  [{'desc': 'Felca fala sobre o assunto de Hytal...  1755293445
# 13  [{'desc': 'a diferença de tamanho kkkkkkkkkkkk...  1744241400
# 14  [{'desc': 'Os problemas do vídeo do Fleca! Cla...  1755017215
#
#                                                  desc  digged  \
# 0   foi preso #felca #felcacamp #edit #fyp @Felca ...   False
# 1    o FELCA de um jeito que a web nunca viu. @Felca    False
# 2   #felca #felcaedit #altashoras #polemica #indir...   False
# 3                           #Hytalo #kamilinha #Felca   False
# 4   Felca contando pra Cela que ele é XYX . . . #f...   False
# 5                                                 NaN   False
# 6   @Felca @Yasmin Yassine  #felca #felcacamp #yas...   False
# 7   Felca> kamilinha  Felca passou o carro no hyta...   False
# 8        ROSAS 🤣 #felca #felcalive #felcaedit #memes    False
# 9                        kkkkkk  #felca #fyp #beamon    False
# 10  Esquerda e Felca - uma análise da situação atu...   False
# 11  A filha perdida do Felca😂😱 #felca #felcacamp #...   False
# 12  Felca fala sobre o assunto de Hytalo Santos #f...   False
# 13  a diferença de tamanho kkkkkkkkkkkk #felca #fe...   False
# 14  Os problemas do vídeo do Fleca! Claro que não ...   False
#
#     diversificationId  ...  moderationAigcLabelType repostList isECVideo  \
# 0             10045.0  ...                      NaN        NaN       NaN
# 1             10000.0  ...                      NaN        NaN       NaN
# 2             10088.0  ...                      NaN        NaN       NaN
# 3             10005.0  ...                      NaN        NaN       NaN
# 4             10075.0  ...                      NaN        NaN       NaN
# 5             10003.0  ...                      NaN        NaN       NaN
# 6                 NaN  ...                      NaN        NaN       NaN
# 7             10075.0  ...                      NaN        NaN       NaN
# 8                 NaN  ...                      NaN        NaN       NaN
# 9             10003.0  ...                      NaN        NaN       NaN
# 10            10087.0  ...                      NaN        NaN       NaN
# 11            10003.0  ...                      NaN        NaN       NaN
# 12                NaN  ...                      NaN        NaN       NaN
# 13            10003.0  ...                      NaN        NaN       NaN
# 14                NaN  ...                      NaN        NaN       NaN
#
#     author.roomId  brandOrganicType  event.event_id  event.event_start_time  \
# 0             NaN               NaN             NaN                     NaN
# 1             NaN               NaN             NaN                     NaN
# 2             NaN               NaN             NaN                     NaN
# 3             NaN               NaN             NaN                     NaN
# 4             NaN               NaN             NaN                     NaN
# 5             NaN               NaN             NaN                     NaN
# 6             NaN               NaN             NaN                     NaN
# 7             NaN               NaN             NaN                     NaN
# 8             NaN               NaN             NaN                     NaN
# 9             NaN               NaN             NaN                     NaN
# 10            NaN               NaN             NaN                     NaN
# 11            NaN               NaN             NaN                     NaN
# 12            NaN               NaN             NaN                     NaN
# 13            NaN               NaN             NaN                     NaN
# 14            NaN               NaN             NaN                     NaN
#
#     event.has_subscribed  event.title  duetInfo.duetFromId
# 0                    NaN          NaN                  NaN
# 1                    NaN          NaN                  NaN
# 2                    NaN          NaN                  NaN
# 3                    NaN          NaN                  NaN
# 4                    NaN          NaN                  NaN
# 5                    NaN          NaN                  NaN
# 6                    NaN          NaN                  NaN
# 7                    NaN          NaN                  NaN
# 8                    NaN          NaN                  NaN
# 9                    NaN          NaN                  NaN
# 10                   NaN          NaN                  NaN
# 11                   NaN          NaN                  NaN
# 12                   NaN          NaN                  NaN
# 13                   NaN          NaN                  NaN
# 14                   NaN          NaN                  NaN
#
# [15 rows x 170 columns]
#        AIGCDescription  CategoryType  backendSourceEventTracking  \
# count              0.0    603.000000                         0.0
# mean               NaN     72.945274                         NaN
# std                NaN     53.327285                         NaN
# min                NaN      0.000000                         NaN
# 25%                NaN      0.000000                         NaN
# 50%                NaN    104.000000                         NaN
# 75%                NaN    117.000000                         NaN
# max                NaN    120.000000                         NaN
#
#          createTime  diversificationId  duetDisplay            id  \
# count  6.030000e+02         395.000000        603.0  6.030000e+02
# mean   1.747213e+09       10044.048101          0.0  7.504219e+18
# std    1.652323e+07          33.531487          0.0  7.096643e+16
# min    1.637546e+09       10000.000000          0.0  7.033205e+18
# 25%    1.747045e+09       10005.000000          0.0  7.503503e+18
# 50%    1.755007e+09       10046.000000          0.0  7.537698e+18
# 75%    1.755474e+09       10075.000000          0.0  7.539702e+18
# max    1.756196e+09       10096.000000          0.0  7.542806e+18
#
#        itemCommentStatus  stitchDisplay  author.UserStoryStatus  ...  \
# count              603.0          603.0              603.000000  ...
# mean                 0.0            0.0                0.116086  ...
# std                  0.0            0.0                0.320594  ...
# min                  0.0            0.0                0.000000  ...
# 25%                  0.0            0.0                0.000000  ...
# 50%                  0.0            0.0                0.000000  ...
# 75%                  0.0            0.0                0.000000  ...
# max                  0.0            0.0                1.000000  ...
#
#        poi.typeCode  aigcLabelType  moderationAigcLabelType  isECVideo  \
# count           0.0        7.00000                      1.0        3.0
# mean            NaN        1.00000                      1.0        1.0
# std             NaN        0.57735                      NaN        0.0
# min             NaN        0.00000                      1.0        1.0
# 25%             NaN        1.00000                      1.0        1.0
# 50%             NaN        1.00000                      1.0        1.0
# 75%             NaN        1.00000                      1.0        1.0
# max             NaN        2.00000                      1.0        1.0
#
#        author.roomId  brandOrganicType  event.event_id  \
# count   3.000000e+00               1.0    2.000000e+00
# mean    7.542877e+18            1001.0    7.540411e+18
# std     0.000000e+00               NaN    0.000000e+00
# min     7.542877e+18            1001.0    7.540411e+18
# 25%     7.542877e+18            1001.0    7.540411e+18
# 50%     7.542877e+18            1001.0    7.540411e+18
# 75%     7.542877e+18            1001.0    7.540411e+18
# max     7.542877e+18            1001.0    7.540411e+18
#
#        event.event_start_time  event.title  duetInfo.duetFromId
# count                     2.0          0.0         1.000000e+00
# mean                      0.0          NaN         7.221287e+18
# std                       0.0          NaN                  NaN
# min                       0.0          NaN         7.221287e+18
# 25%                       0.0          NaN         7.221287e+18
# 50%                       0.0          NaN         7.221287e+18
# 75%                       0.0          NaN         7.221287e+18
# max                       0.0          NaN         7.221287e+18
#
# [8 rows x 76 columns]

# %% [markdown]
# > Comentário:

# %% [markdown]
# ### 2) Qual a média e a mediana dos likes, comentários, compartilhamentos e plays, por autor? (0,1)
#
# Calcule a média e a mediana dos likes, comentários, compartilhamentos e plays, por autor. (0,05)
#
# Abaixo do código, faça um comentário interpretativo sobre o que você observou nos resultados. (0,05)

# %%
df_limpo= df['author.nickname','authorStats.heartCount','stats.commentCount']

# %% [markdown]
# > Comentário:

# %% [markdown]
# ### 3) Qual a média da proporção, por usuário, de comentários por like? Ou seja, a cada like, quantos comentários cada usuário recebe? Organize por quem engaja mais (nesse caso, quem tem mais comentários por like) usando o método .sort_values(). (0,1)
#
# Calcule a proporção de comentários por like em cada vídeo, e depois, a média dessa proporção por autor. Organize por ordem decrescente a partir dessa métrica criada. (0,05)
#
# Abaixo do código, faça um comentário interpretativo sobre o que você observou nos resultados. (0,05)

# %% [markdown]
# > Comentário:

# %% [markdown]
# ### 4) Crie um gráfico de barras que mostre a quantidade de vídeos por autor. (0,1)
#
# Crie um gráfico de barras que mostre a quantidade de vídeos por autor, utilizando o seaborn ou matplotlib (0,05)
#
# Abaixo do gráfico, faça um comentário interpretativo sobre o que você observou nos resultados. (0,05)

# %% [markdown]
# > Comentário:

# %% [markdown]
# ### 5) Faça uma nuvem de palavras com as 100 hashtags mais utilizadas na base. (0,1)
#
# Faça uma nuvem de palavras com as 100 hashtags mais utilizadas na base. (0,05)
#
# Abaixo do gráfico, faça um comentário interpretativo sobre o que você observou nos resultados. (0,05)

# %% [markdown]
# > Comentário:

# %% [markdown]
# # Extra: 0,1
#
# Identifique o tema do dataset com base nas análises anteriores.

# %% [markdown]
# # Resposta:
